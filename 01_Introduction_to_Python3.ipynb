# %%
# Each print statement starts on a new Line

print( 'Hello there. ' )
print( 'My name is...' )
print('Dhruva' )
# Out:
# Hello there.
# My name is...
# Dhruva

# %%
# Including end=' ' keeps output on same Line
print( 'Hello everyone.',end= ' ' )
print( 'My name is... ' ,end=' ' )
print( 'Shravani' )
# Out:
# Hello everyone. My name is...  Shravani

# %%
wage = 50

print( 'Wage is',end=' ' )
print(wage) # print variable's value
print('GoodDay')
# Out:
# Wage is 50
# GoodDay

# %%
wage = 20

print( 'Wage:', wage ) # Comma separates multiple items
print('Goodbye.')

# %%
print( '100\n200\n300')
# Out:
# 100
# 200
# 300

# %%
print( 'c202 ')
print(   )
print( 'shivheights')
# Out:
# c202
#
# shivheights

# %% [markdown]
# # Input Function

# %%
print( 'Enter name of best friend:')
best_friend = input()
print('My best friend is', best_friend)
# Out:
# Enter name of best friend:
# My best friend is smita

# %%
my_string = '123'
my_int=int('453')

print(my_string)
print(my_int)
# Out:
# 123
# 453

# %%
print( 'Enter wage:', end=' ')
wage = int(input())
print('Wage is', wage)

new_wage = wage + 50
print('New wage:', new_wage )
# Out:
# Enter wage: Wage is 100
# New wage: 150

# %%
hours = 40
weeks = 52
hourly_wage = int(input('Enter hourly wage: '))
print('Hourly wage is', hourly_wage)

print( ' Salary is', hourly_wage * hours * weeks )
# Out:
# Hourly wage is 25
#  Salary is 52000

# %% [markdown]
# ## Errors

# %%
print('Current Monthly salary is' , end=' ')
print('Current Annual  salary is' , end=' ')

print(45000)
print (6000)
# Out:
# Current Monthly salary is Current Annual  salary is 45000
# 6000

# %%
print('Enter current  salary: ',end=' ' )
current_sal = int(input())
print('Enter  current salary:',end=' ' )
current_sal = int(input())

print ( 'Current Annual salary is', current_sal * 12 )
# Out:
# Enter current  salary:  Enter  current salary: Current Annual salary is 60000

# %%
print(new_sal)print(user_num)

# %%
print(new_sal)

print(user_num)

# %%
print( 'Salary is',end=' ')
print(20*40*50)

# %%
print('Enter integer:', end=' ')
user_num = int(input())
print(user_num)
# Out:
# Enter integer:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 print('Enter integer:', end=' ')
# ----> 2 user_num = int(input())
#       3 print(user_num)
#
# ValueError: invalid literal for int() with base 10: 'ha'

# %% [markdown]
# ## ValueError: invalid Literal for int() with base 10: 'Anup'

# %%
print('Enter integer:', end=' ')
user_num = int(input())
print(user_num)
## pass the input as 'Anup'

# %% [markdown]
# ## Logical Error

# %%
current_ salary = int(input('Enter current salary: ' ) )
raise_percentage = 5 # Logic error gives a 500% raise instead of 5%
new_salary = current_salary+(current_salary * raise_percentage)
print( 'New salary:',new_salary)
# Out:
# New salary: 300

# %%
current_salary = int(input('Enter current salary: ' ) )
raise_percentage = 5 # Logic error gives a 500% raise instead of 5%
new_salary = current_salary+(current_salary * raise_percentage)
print( 'New salary:',new_salary)

# %% [markdown]
# ## Python example: Salary calculation

# %%
hourly_wage = 20

print('Annua1 salary is: ')
print(hourly_wage * 40 * 50)
print('Monthly salary is: ')
print(((hourly_wage *40 * 50) / 12))
print()

## FIXME: The above is worng. change
##       the 1 so that the statement
##       outputs monthly salary.
# Out:
# Annua1 salary is:
# 40000
# Monthly salary is:
# 3333.3333333333335
